# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv(Path('../Resources/oil_gweekly.csv'))
df.head()
df = df.dropna()

# %%
oildf= df[['my','week','value_x','value_y']]
#oil_gdf = oil_gdf[['my',  'value','year']]

# %%
plt.scatter(oildf.value_x, oildf.value_y)
plt.xlabel('oil price$')
plt.ylabel('gas price$')
plt.show()

# %%
X = oildf.value_x.values.reshape(-1, 1)

# %%
X[:10]
# Out:
# array([[ 89.528     ],
#        [ 91.0732    ],
#        [ 90.434     ],
#        [ 88.09333333],
#        [102.3875    ],
#        [100.444     ],
#        [100.059     ],
#        [ 99.20714286],
#        [ 93.08      ],
#        [ 93.554     ]])

# %%
X.shape
# Out:
# (483, 1)

# %%
y = oildf.value_y

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (483,)

# %%
plt.figure(figsize=(8,8))
plt.scatter(X, y, s=10, marker='x')
plt.plot(X, y_pred, color='red')
plt.xlabel('oil price ($)')
plt.ylabel('gas price ($)')
# plt.xlim(0, 100)
# plt.ylim(0, 5)
# plt.figure(figsize=(20, 20), dpi=80)
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.02129244]
# 1.5094100291859884

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
    y, test_size=.3, random_state=0)

# %% [markdown]
# # split

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
#training the algorithm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#To retrieve the intercept:
print(regressor.intercept_)
#For retrieving the slope:
print(regressor.coef_)
# Out:
# 1.4716292889560632
# [0.02181777]

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([3.59040735, 3.84670287, 2.70813824, 2.64826156, 3.66115147,
#        2.72867562, 2.48130326, 2.70730044, 2.72222379, 2.15614869,
#        2.451858  , 2.01490918, 3.39739646, 3.37566597, 3.61413418,
#        2.78032887, 2.70389687, 2.33364933, 2.49490446, 2.96674644,
#        2.71382395, 2.25188724, 3.14602959, 2.75678314, 2.56714309,
#        2.64471617, 3.70973964, 2.72885639, 2.58535366, 2.4676977 ,
#        2.74913819, 3.52522677, 2.54411807, 3.0019974 , 3.52789945,
#        3.65073348, 2.9361252 , 2.6168876 , 2.41188785, 3.21063636,
#        3.53955014, 2.63231277, 3.40937442, 2.44775626, 3.47984269,
#        3.4586433 , 3.37451399, 2.66839499, 2.46390141, 2.49280995,
#        2.56426315, 3.16275072, 2.90265674, 3.50940889, 2.6279274 ,
#        2.57128847, 2.91915097, 2.54004542, 2.53184194, 2.50412465,
#        3.63780646, 2.73050582, 2.97533718, 3.26966652, 3.01292374,
#        3.76947669, 2.54937252, 2.57011031, 3.59864356, 3.55855341,
#        2.36838322, 3.70964146, 2.59582909, 2.50235523, 3.18295273,
#        3.59847993, 2.620073  , 2.57665564, 3.10722014, 2.15218004,
#        2.75119779, 2.84562509, 2.43876734, 3.65469341, 3.50343082,
#        3.52446315, 3.02632713, 2.71552137, 3.63610779, 2.70364233,
#        3.5024272 , 3.51215793, 3.17869515, 2.53598186, 2.25583844,
#        2.46320324, 3.7312956 , 2.61666943, 2.89496598, 2.81691291,
#        3.26694366, 2.97674365, 2.55226337, 3.81837966, 3.5989981 ,
#        3.35164024, 3.35574634, 2.60261878, 2.629411  , 3.59675269,
#        3.64847535, 2.94615264, 3.70677242, 3.55184445, 3.67626027,
#        2.63695995, 2.98202978, 2.83643981, 3.79346751, 3.29141302,
#        3.40666465, 2.68605866, 2.62060753, 2.03545498, 2.86427928,
#        3.58663506, 2.45163982, 3.60418528, 2.70500957, 2.61117135,
#        3.0411123 , 3.70549608, 2.71139672, 3.66309325, 2.43011878,
#        3.66153328, 3.61453417, 3.31055551, 2.1068209 , 2.86131207,
#        2.23508756, 3.77978559, 3.53176119, 2.50791221, 2.59935339])

# %%
#df2 = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
#df2

# %%
df2 = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df2
# Out:
#       Actual  Predicted
# 15   3.42225   3.590407
# 124  3.84550   3.846703
# 141  2.55925   2.708138
# 263  2.84950   2.648262
# 170  3.95300   3.661151
# ..       ...        ...
# 20   2.08375   2.235088
# 295  3.65425   3.779786
# 14   3.42225   3.531761
# 313  2.56125   2.507912
# 354  2.84275   2.599353
#
# [145 rows x 2 columns]

# %%
df1 = df2.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
